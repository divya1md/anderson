# %%
from tabula import read_pdf

# %%
df1 = read_pdf("base1.pdf", pages="all")

# %%
df1.to_csv("base1.csv")

# %%
import pandas as pd
data = pd.read_csv("base1.csv", index_col ="UID" )

# %%
data.drop(["UID"], inplace = True)

# %%
data.to_csv("base1.csv")

# %%
data.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
data.to_csv("base1.csv")

# %%
data.head()
# Out:
#     Product #                               Product Description  Qty  \
# UID
# 1       100-1                                 400 Series Awning    1
# NaN       NaN  Overall Joined Rough Opening = 99 1/4" x 24 5/8"  NaN
# NaN       NaN           Overall Joined Unit = 98 3/4" x 24 1/8"  NaN
# NaN       NaN                     Installation Zip Code = 55082  NaN
# NaN       NaN         U.S. ENERGY STAR® Climate Zone = Northern  NaN
#
#     Unit Price Total Price
# UID
# 1    $2,299.30   $2,299.30
# NaN        NaN         NaN
# NaN        NaN         NaN
# NaN        NaN         NaN
# NaN        NaN         NaN

# %%
data = data.reset_index()

# %%
if 'UID' in data.columns:
    print("Yes")
else:
    print("No")
# Out:
# Yes

# %%
for col in data.columns: 
    print(col)
# Out:
# UID
# Product #
# Product Description
# Qty
# Unit Price
# Total Price

# %%
data.head()
# Out:
#    UID Product #                               Product Description  Qty  \
# 0    1     100-1                                 400 Series Awning    1
# 1  NaN       NaN  Overall Joined Rough Opening = 99 1/4" x 24 5/8"  NaN
# 2  NaN       NaN           Overall Joined Unit = 98 3/4" x 24 1/8"  NaN
# 3  NaN       NaN                     Installation Zip Code = 55082  NaN
# 4  NaN       NaN         U.S. ENERGY STAR® Climate Zone = Northern  NaN
#
#   Unit Price Total Price
# 0  $2,299.30   $2,299.30
# 1        NaN         NaN
# 2        NaN         NaN
# 3        NaN         NaN
# 4        NaN         NaN

# %%
data.to_csv("base1.csv")

# %%
data.to_dict()
# Out:
# {'UID': {0: '1',
#   1: nan,
#   2: nan,
#   3: nan,
#   4: nan,
#   5: nan,
#   6: nan,
#   7: nan,
#   8: nan,
#   9: nan,
#   10: nan,
#   11: nan,
#   12: nan,
#   13: nan,
#   14: nan,
#   15: nan,
#   16: nan,
#   17: nan,
#   18: nan,
#   19: nan,
#   20: nan,
#   21: nan,
#   22: nan,
#   23: nan,
#   24: nan,
#   25: nan,
#   26: nan,
#   27: nan,
#   28: nan,
#   29: nan,
#   30: nan,
#   31: nan,
#   32: nan,
#   33: nan,
#   34: nan,
#   35: nan,
#   36: nan,
#   37: nan,
#   38: nan,
#   39: nan,
#   40: nan,
#   41: nan,
#   42: nan,
#   43: nan,
#   44: nan,
#   45: nan,
#   46: nan,
#   47: nan,
#   48: nan,
#   49: nan,
#   50: nan,
#   51: nan,
#   52: nan,
#   53: nan,
#   54: nan,
#   55: nan,
#   56: '2',
#   57: nan,
#   58: nan,
#   59: nan,
#   60: nan,
#   61: nan,
#   62: nan,
#   63: nan,
#   64: nan,
#   65: nan,
#   66: nan,
#   67: nan,
#   68: nan,
#   69: nan,
#   70: nan,
#   71: nan,
#   72: nan,
#   73: nan,
#   74: nan,
#   75: nan,
#   76: nan,
# ...

# %%
df2 = read_pdf("cycle.pdf", pages="all")

# %%
df2.to_csv("cycle.csv")

# %%
import pandas as pd
data1 = pd.read_csv("cycle.csv", index_col ="UID" )

# %%
data1.drop(["UID"], inplace = True)

# %%
data1.to_csv("cycle.csv")

# %%
data1.drop(["Unnamed: 0"], axis = 1, inplace = True)

# %%
data1.to_csv("cycle.csv")

# %%
data1 = data1.reset_index()

# %%
data1.head()

# %%
data1.to_csv("cycle.csv")
