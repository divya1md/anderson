# %%
import xml.etree.ElementTree as ET
from xlwt import Workbook 
import xlwt 
#Workbook is created 
wb = Workbook() 
import pandas as pd
#add_sheet is used to create sheet. 
# sheet1 = wb.add_sheet('Sheet 1', cell_overwrite_ok=True) 
tree = ET.parse('E:/offc_work/anderson/xmltcsv/Quick Quote-20191025T162809Z-001/C_13556.xml_2019_09_27_15_06_28_086.xml')
root = tree.getroot()

q,q1,q2,q3,q4,q5,q6,q7,q8,q9,q10,q11,q12=[],[],[],[],[],[],[],[],[],[],[],[],[]

for child in root.findall('./LineItemMasters/LineItemMaster/LineItems/LineItem'):
    print(child.tag)

    a=child.find("LineItemNumber").text
    print(a)
    q=q+[a]

    b=child.find("LineItemName").text
    q1=q1+[b]

    c=child.find("ConfiguratorType").text
    q2=q2+[c]

    d=child.find("ConfiguratorPKVersion").text
    q3=q3+[d]

    f=child.find("LineItemID").text
    q5=q5+[f]

    g=child.find("ParentLineItemID").text
    q6=q6+[g]

    h=child.find("LinePrice").text
    q7=q7+[h]

    i=child.find("Cost").text
    q8=q8+[i]

    j=child.find("Description").text
    q9=q9+[j]

    k=child.find("Quantity").text
    q10=q10+[k]

    m=child.find("LongDescription").text
    q12=q12+[m]

for child in root.findall('./LineItemMasters/LineItemMaster/LineItems/LineItem/LICustomDataXML'):
	print(child.tag)
	l=child.find("EDIDescription").text
	q11=q11+[l]
df=pd.DataFrame()
df['LineItemNumber']=q
df['LineItemName']=q1
df['ConfiguratorType']=q2
df['ConfiguratorPKVersion']=q3

df['LineItemID']=q5
df['ParentLineItemID']=q6
df['LinePrice']=q7
df['Cost']=q8
df['Description']=q9
df['Quantity']=q10
df['EDIDescription']=q11
df['LongDescription']=q12
print(df['LongDescription'])
df.to_excel('E:/offc_work/anderson/xmltcsv/Quick Quote-20191025T162809Z-001/C_13556.xml_2019_09_27_15_06_28_086.xlsx')
# Out:
# LineItem
# 1
# LineItem
# 2
# LineItem
# 3
# LineItem
# 4
# LineItem
# 5
# LineItem
# 6
# LineItem
# 1
# LineItem
# 2
# LineItem
# 3
# LineItem
# 4
# LineItem
# 5
# LineItem
# 6
# LineItem
# 7
# LineItem
# 8
# LineItem
# 9
# LineItem
# 10
# LineItem
# 11
# LineItem
# 12
# LineItem
# 13
# LineItem
# 1
# LineItem
# 2
# LineItem
# 3
# LineItem
# 4
# LineItem
# 5
# LineItem
# 6
# LineItem
# 7
# LineItem
# 8
# LineItem
# 9
# LineItem
# 10
# LineItem
# 11
# LineItem
# 12
# LineItem
# 1
# LineItem
# 2
# LineItem
# 3
# LineItem
# 4
# LineItem
# 5
# LineItem
# 6
# LineItem
# 7
# LineItem
# 8
# LineItem
# 9
# LineItem
# 10
# LineItem
# 11
# LineItem
# 12
# LineItem
# 1
# LineItem
# 1
# LineItem
# 2
# LineItem
# 3
# LineItem
# 1
# LineItem
# 1
# LineItem
# 2
# LineItem
# 3
# LineItem
# 4
# LineItem
# 5
# LineItem
# 6
# LineItem
# 1
# LineItem
# 2
# LineItem
# 3
# LineItem
# 4
# LineItem
# 5
# LineItem
# 1
# LineItem
# 2
# LineItem
# 3
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# LICustomDataXML
# 0     400 Series Awning\nOverall Joined Rough Openin...
# 1     400 Series Awning\nOverall Joined Rough Openin...
# 2     400 Series Awning\nOverall Joined Rough Openin...
# 3     400 Series Awning\nOverall Joined Rough Openin...
# 4     400 Series Awning\nOverall Joined Rough Openin...
# 5     400 Series Awning\nOverall Joined Rough Openin...
# 6     A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 7     A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 8     A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 9     A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 10    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 11    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 12    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 13    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 14    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 15    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 16    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 17    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 18    A Series Patio Doors 2 Panel-FWG\nOverall Roug...
# 19    400 Series Double-Hung Bay\nOverall Joined Rou...
# 20    400 Series Double-Hung Bay\nOverall Joined Rou...
# 21    400 Series Double-Hung Bay\nOverall Joined Rou...
# 22    400 Series Double-Hung Bay\nOverall Joined Rou...
# 23    400 Series Double-Hung Bay\nOverall Joined Rou...
# 24    400 Series Double-Hung Bay\nOverall Joined Rou...
# 25    400 Series Double-Hung Bay\nOverall Joined Rou...
# 26    400 Series Double-Hung Bay\nOverall Joined Rou...
# 27    400 Series Double-Hung Bay\nOverall Joined Rou...
# 28    400 Series Double-Hung Bay\nOverall Joined Rou...
# 29    400 Series Double-Hung Bay\nOverall Joined Rou...
#                             ...
# 32    400 Series Casement Bow\nOverall Joined Rough ...
# 33    400 Series Casement Bow\nOverall Joined Rough ...
# 34    400 Series Casement Bow\nOverall Joined Rough ...
# 35    400 Series Casement Bow\nOverall Joined Rough ...
# 36    400 Series Casement Bow\nOverall Joined Rough ...
# 37    400 Series Casement Bow\nOverall Joined Rough ...
# 38    400 Series Casement Bow\nOverall Joined Rough ...
# 39    400 Series Casement Bow\nOverall Joined Rough ...
# 40    400 Series Casement Bow\nOverall Joined Rough ...
# 41    400 Series Casement Bow\nOverall Joined Rough ...
# 42    400 Series Casement Bow\nOverall Joined Rough ...
# 43    100 Series Single Casement-CW\nParts and Acces...
# 44    400 Series Specialty Equal Leg Arch\nOverall R...
# 45    400 Series Specialty Equal Leg Arch\nOverall R...
# 46    400 Series Specialty Equal Leg Arch\nOverall R...
# 47    100 Series Specialty Trapezoid\nOverall Rough ...
# 48    400 Series Double-Hung\nOverall Joined Rough O...
# 49    400 Series Specialty Half Circle-DH\nOverall J...
# 50    400 Series Specialty Half Circle-DH\nOverall J...
# 51    400 Series Specialty Half Circle-DH\nOverall J...
# 52    400 Series Specialty Half Circle-DH\nOverall J...
# 53    400 Series Specialty Half Circle-DH\nOverall J...
# 54    400 Series Twin Vertical Awning\nOverall Rough...
# 55    400 Series Twin Vertical Awning\nOverall Rough...
# 56    400 Series Twin Vertical Awning\nOverall Rough...
# 57    400 Series Twin Vertical Awning\nOverall Rough...
# 58    400 Series Twin Vertical Awning\nOverall Rough...
# 59    400 Series Triple Horizontal Awning\nOverall R...
# 60    400 Series Triple Horizontal Awning\nOverall R...
# 61    400 Series Triple Horizontal Awning\nOverall R...
# Name: LongDescription, Length: 62, dtype: object

# %%
import pandas as pd

df1 = pd.read_excel('B_13436.xml_2019_08_21_13_44_50_529.xlsx')
df2 = pd.read_excel('C_13556.xml_2019_09_27_15_06_28_086.xlsx')

# %%
import re
for i in range(0, len(df1["EDIDescription"])):
    s=df1["EDIDescription"][i]
    k=re.search(r'{(.*?)}', s).group(1)
    df=k+str(df1["LineItemNumber"][i])
    df=df.strip("#")
    df1["UID"][i]=df

    
print(df1)

df1.to_excel("B1.xlsx",index=False)
# Out:
# c:\python35\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
#     LineItemNumber LineItemName ConfiguratorType  ConfiguratorPKVersion  \
# 0                1   Unassigned    WindowAndDoor                    254
# 1                2   Unassigned    WindowAndDoor                    254
# 2                3   Unassigned    WindowAndDoor                    254
# 3                4   Unassigned    WindowAndDoor                    254
# 4                5   Unassigned    WindowAndDoor                    254
# 5                6   Unassigned    WindowAndDoor                    254
# 6                1   Unassigned    WindowAndDoor                    254
# 7                2   Unassigned    WindowAndDoor                    254
# 8                3   Unassigned    WindowAndDoor                    254
# 9                4   Unassigned    WindowAndDoor                    254
# 10               5   Unassigned    WindowAndDoor                    254
# 11               6   Unassigned    WindowAndDoor                    254
# 12               7   Unassigned    WindowAndDoor                    254
# 13               8   Unassigned    WindowAndDoor                    254
# 14               9   Unassigned    WindowAndDoor                    254
# 15              10   Unassigned    WindowAndDoor                    254
# 16              11   Unassigned    WindowAndDoor                    254
# 17              12   Unassigned    WindowAndDoor                    254
# 18              13   Unassigned    WindowAndDoor                    254
# 19               1   Unassigned    WindowAndDoor                    254
# 20               2   Unassigned    WindowAndDoor                    254
# 21               3   Unassigned    WindowAndDoor                    254
# 22               4   Unassigned    WindowAndDoor                    254
# 23               5   Unassigned    WindowAndDoor                    254
# 24               6   Unassigned    WindowAndDoor                    254
# 25               7   Unassigned    WindowAndDoor                    254
# 26               8   Unassigned    WindowAndDoor                    254
# 27               9   Unassigned    WindowAndDoor                    254
# 28              10   Unassigned    WindowAndDoor                    254
# 29              11   Unassigned    WindowAndDoor                    254
# ..             ...          ...              ...                    ...
# 32               2   Unassigned    WindowAndDoor                    254
# 33               3   Unassigned    WindowAndDoor                    254
# 34               4   Unassigned    WindowAndDoor                    254
# 35               5   Unassigned    WindowAndDoor                    254
# 36               6   Unassigned    WindowAndDoor                    254
# 37               7   Unassigned    WindowAndDoor                    254
# 38               8   Unassigned    WindowAndDoor                    254
# 39               9   Unassigned    WindowAndDoor                    254
# 40              10   Unassigned    WindowAndDoor                    254
# 41              11   Unassigned    WindowAndDoor                    254
# 42              12   Unassigned    WindowAndDoor                    254
# 43               1   Unassigned    WindowAndDoor                    254
# 44               1   Unassigned    WindowAndDoor                    254
# 45               2   Unassigned    WindowAndDoor                    254
# 46               3   Unassigned    WindowAndDoor                    254
# 47               1   Unassigned    WindowAndDoor                    254
# 48               1   Unassigned    WindowAndDoor                    254
# 49               2   Unassigned    WindowAndDoor                    254
# 50               3   Unassigned    WindowAndDoor                    254
# 51               4   Unassigned    WindowAndDoor                    254
# 52               5   Unassigned    WindowAndDoor                    254
# 53               6   Unassigned    WindowAndDoor                    254
# 54               1   Unassigned    WindowAndDoor                    254
# 55               2   Unassigned    WindowAndDoor                    254
# 56               3   Unassigned    WindowAndDoor                    254
# 57               4   Unassigned    WindowAndDoor                    254
# 58               5   Unassigned    WindowAndDoor                    254
# 59               1   Unassigned    WindowAndDoor                    254
# 60               2   Unassigned    WindowAndDoor                    254
# 61               3   Unassigned    WindowAndDoor                    254
#
#                               LineItemID  \
# 0   126baeb8-c1e3-4732-be07-501c1c74b47d
# 1   5eec9366-7048-4bab-8644-f0be838f43d1
# 2   fa1096be-707a-4562-af96-3c423d4cc76c
# 3   53c51b80-ec1b-4fb4-ae95-d794449a984f
# 4   7ffab007-f4f2-4560-89b0-6a46b32f6581
# 5   a7071938-83fc-459b-beb7-c9b67296a2a3
# 6   f1059a9b-d5fe-442b-8f2e-35e8f334d772
# 7   6ea38e6e-9b63-4cb3-9de2-ba2c6c06b610
# 8   06827029-c3b5-4ac2-8126-6a476a66b071
# 9   213951ff-31e8-461b-b1f8-908671c68a5b
# 10  770937a4-bd4e-4c66-b0aa-16f1a0a19e39
# 53  00000000-0000-0000-0000-000000000000     $31.90  $0.00
# 54  00000000-0000-0000-0000-000000000000  $1,019.30  $0.00
# 55  00000000-0000-0000-0000-000000000000     $84.30  $0.00
# 56  00000000-0000-0000-0000-000000000000     $95.00  $0.00
# 57  00000000-0000-0000-0000-000000000000    $236.80  $0.00
# 58  00000000-0000-0000-0000-000000000000    $139.90  $0.00
# 59  00000000-0000-0000-0000-000000000000    $934.70  $0.00
# 60  00000000-0000-0000-0000-000000000000    $333.70  $0.00
# 61  00000000-0000-0000-0000-000000000000    $490.80  $0.00
#
#                                           Description  Quantity  \
# 0   400 Series Awning , Vent(All) Vent , 98.75 x 2...         1
# 1   Hardware: PSA   Classic Series White PN:152102...         1
# 2   Hardware: PSA   Classic Series White PN:152102...         1
# 3   Hardware: PSA   Classic Series White PN:152102...         1
# 4   Hardware: PSA   Classic Series White PN:152102...         1
# 5   Exterior Trim: PSA  98.75 x 24.125  3 1/2" Fla...         1
# 6   A Series Patio Doors 2 Panel-FWG , Stationary-...         1
# 7   FWG200/400, KIT, SECURITY SENSOR VERILOCK PN:9...         1
# 8      FWG200/400, KIT, LOCK EXTENSION KIT PN:9140492         1
# 9   Trim Set 1: FWGD Stationary-Right Newbury Brus...         1
# 10  Auxiliary Foot Lock 1: FWGD Oil Rubbed Bronze ...         1
# 11  Exterior Keyed Lock 1: FWGD RH Newbury Brushed...         1
# 12  Insect Screen 1: A Series Patio Doors 2 Panel-...         1
# 13  Threshold: FWGD8080 Maple w/Screws PN:1207060 ...         1
# 14  Panel 1:  Left Slab  FWGD8080 Stationary-Right...         1
# 15  Panel 2:  Right Slab  FWGD8080 Stationary-Righ...         1
# 16  Exterior Trim: [Configuration_Size] FWGD8080 3...         1
# 17  Decorative Trim: [Configuration_Size] FWGD8080...         1
# 18  Extension Jamb 1: [Configuration_Size] FWGD808...         1
# 19  400 Series Double-Hung Bay Equal Sash , Active...         1
# 20  Sash Lift: TW Hand Lift Traditional Antique Br...         1
# 21  Insect Screen 1: 400 Series Double-Hung Bay TW...         1
# 22  Sash Lift: TW Hand Lift Traditional Antique Br...         1
# 23  Insect Screen 1: 400 Series Double-Hung Bay TW...         1
# 24  Sash Lift: TW Hand Lift Traditional Antique Br...         1
# 25  Insect Screen 1: 400 Series Double-Hung Bay TW...         1
# 26  Extension Jamb 1: TW TW45-3456-18 White - Pain...         1
# 27  DH45-34-18, HEAD AND SEAT BOARD, WHITE 45 DEG ...         1
# 28  Angle Bay/Bow Supports: Frame: , TW45-3456-18 ...         1
# 29  Top Auxiliary Casing: TW45-3456-18 45 Top Auxi...         1
# ..                                                ...       ...
# 32  Grille 1: C56-BOW RIG Colonial   2W 6H 7/8" Wh...         1
# 33  Grille 1: C56-BOW RIG Colonial   2W 6H 7/8" Wh...         1
# 34  Hardware: PSC   Contemporary Folding Bright Br...         1
# 35  Insect Screen 1: 400 Series Casement Bow C56-B...         1
# 36  Grille 1: C56-BOW RIG Colonial   2W 6H 7/8" Wh...         1
# 37  Grille 1: C56-BOW RIG Colonial   2W 6H 7/8" Wh...         1
# 38  Grille 1: C56-BOW RIG Colonial   2W 6H 7/8" Wh...         1
# 39  Extension Jamb 1: PSC C56-BOW White - Painted ...         1
# 40  C5, HEAD AND SEAT BOARD, WHITE 10 DEGREE BOW 5...         1
# 41  Angle Bay/Bow Supports: Frame: , C56-BOW 10 w/...         1
# 42  Top Auxiliary Casing: C56-BOW 10 Top Auxiliary...         1
# 43      100CW, HANDLE, WHITE OPERATOR LEFT PN:9123321         1
# 44  400 Series Specialty Equal Leg Arch , Fixed , ...         1
# 45  Exterior Trim: [Configuration_Size] AFC22 3 1/...         1
# 46  Arch Casing: AFC22 2 1/4" Colonial Oak Unfinis...         1
# 47  100 Series Specialty Trapezoid , Fixed , 55 x ...         1
# 48  400 Series Double-Hung Equal Sash , AA , 41.62...         1
# 49  400 Series Specialty Half Circle-DH , Fixed , ...         1
# 50     UNI, KIT, CANVAS SENSOR OPEN/CLOSED PN:9140763         1
# 51  Arch Casing: TW3462 2 1/4" Colonial Pine Unfin...         1
# 52  CTN62, JOINING KIT, WHITE ONE-WAY LVL REIN 4 9...         1
# 53  TW/CSMT, 74INCH, CASING, WHITE 3/4 LVL 2 3/8 P...         1
# 54  400 Series Twin Vertical Awning , Vent/Station...         1
# 55  Hardware: PSA   Contemporary Folding Oil Rubbe...         1
# 56  Insect Screen 1: 400 Series Twin Vertical Awni...         1
# 57  Exterior Trim: [Configuration_Size] A212 3 1/2...         1
# 58  Decorative Trim: [Configuration_Size] A212 Cor...         1
# 59  400 Series Triple Horizontal Awning , Stationa...         1
# 60  Exterior Trim: [Configuration_Size] AR3251 3 1...         1
# 61  Decorative Trim: [Configuration_Size] AR3251 C...         1
#
#                                        EDIDescription  UID
# 0   {#1} |AWDESC=400 Awning, Mull using Number Wid...   11
# 1   ATT TO {#1} |AWDESC=Hardware: PSA   Classic Se...   12
# 2   ATT TO {#1} |AWDESC=Hardware: PSA   Classic Se...   13
# 3   ATT TO {#1} |AWDESC=Hardware: PSA   Classic Se...   14
# 4   ATT TO {#1} |AWDESC=Hardware: PSA   Classic Se...   15
# 5   ATT TO {#1} |AWDESC=Exterior Trim: PSA  98.75 ...   16
# 6   {#2} |AWDESC=A Series Patio Doors 2 Panel-FWG,...   21
# 7   ATT TO {#2} |AWDESC=Safety and Security 1:  PN...   22
# 8   ATT TO {#2} |AWDESC=Safety and Security 1 miss...   23
# 9   ATT TO {#2} |AWDESC=Trim Set 1: FWGD Stationar...   24
# 10  ATT TO {#2} |AWDESC=Auxiliary Foot Lock 1: FWG...   25
# 11  ATT TO {#2} |AWDESC=Exterior Keyed Lock 1: FWG...   26
# 12  ATT TO {#2} |AWDESC=Insect Screen 1: A Series ...   27
# 13  ATT TO {#2} |AWDESC=Threshold: FWGD8080 Maple ...   28
# 14  ATT TO {#2} |AWDESC=Panel 1:  Left Slab  FWGD8...   29
# 15  ATT TO {#2} |AWDESC=Panel 2:  Right Slab  FWGD...  210
# 16  ATT TO {#2} |AWDESC=Exterior Trim: [Configurat...  211
# 17  ATT TO {#2} |AWDESC=Decorative Trim: [Configur...  212
# 18  ATT TO {#2} |AWDESC=Extension Jamb 1: [Configu...  213
# 19  {#3} |AWDESC=400 Double-Hung Bay, Mull using N...   31
# 20  ATT TO {#3} |AWDESC=Sash Lift: TW Hand Lift Tr...   32
# 21  ATT TO {#3} |AWDESC=Insect Screen 1: 400 Serie...   33
# 22  ATT TO {#3} |AWDESC=Sash Lift: TW Hand Lift Tr...   34
# 23  ATT TO {#3} |AWDESC=Insect Screen 1: 400 Serie...   35
# 24  ATT TO {#3} |AWDESC=Sash Lift: TW Hand Lift Tr...   36
# 25  ATT TO {#3} |AWDESC=Insect Screen 1: 400 Serie...   37
# 26  ATT TO {#3} |AWDESC=Extension Jamb 1: TW TW45-...   38
# 27  ATT TO {#3} |AWDESC=Head and Seat Board: TW Fr...   39
# 28  ATT TO {#3} |AWDESC=Angle Bay/Bow Supports: Fr...  310
# 29  ATT TO {#3} |AWDESC=Top Auxiliary Casing: TW45...  311
# ..                                                ...  ...
# 32  ATT TO {#4} |AWDESC=Grille 1: C56-BOW RIG Colo...   42
# 33  ATT TO {#4} |AWDESC=Grille 1: C56-BOW RIG Colo...   43
# 34  ATT TO {#4} |AWDESC=Hardware: PSC   Contempora...   44
# 35  ATT TO {#4} |AWDESC=Insect Screen 1: 400 Serie...   45
# 36  ATT TO {#4} |AWDESC=Grille 1: C56-BOW RIG Colo...   46
# 37  ATT TO {#4} |AWDESC=Grille 1: C56-BOW RIG Colo...   47
# 38  ATT TO {#4} |AWDESC=Grille 1: C56-BOW RIG Colo...   48
# 39  ATT TO {#4} |AWDESC=Extension Jamb 1: PSC C56-...   49
# 40  ATT TO {#4} |AWDESC=Head and Seat Board: PSC F...  410
# 41  ATT TO {#4} |AWDESC=Angle Bay/Bow Supports: Fr...  411
# 42  ATT TO {#4} |AWDESC=Top Auxiliary Casing: C56-...  412
# 43  {#5} |AWDESC=100 Single Casement-CW, Parts/Acc...   51
# 44  {#6} |AWDESC=400 Specialty Equal Leg Arch, 48 ...   61
# 45  ATT TO {#6} |AWDESC=Exterior Trim: [Configurat...   62
# 46  ATT TO {#6} |AWDESC=Arch Casing: AFC22 2 1/4" ...   63
# 47  {#7} |AWDESC=100 Series Specialty Trapezoid, 5...   71
# 48  {#8} |AWDESC=400 Double-Hung, Mulled Units, Eq...   81
# 49  ATT TO {#8} |AWDESC=400 Specialty Half Circle-...   82
# 50  ATT TO {#8} |AWDESC=Safety and Security 1:  PN...   83
# 51  ATT TO {#8} |AWDESC=Arch Casing: TW3462 2 1/4"...   84
# 52  ATT TO {#8} |AWDESC=Join Mull Material: 400 Se...   85
# 53  ATT TO {#8} |AWDESC=Mull Casing: TW, 74, Horiz...   86
# 54  {#9} |AWDESC=400 Twin Vertical Awning, 24 1/8 ...   91
# 55  ATT TO {#9} |AWDESC=Hardware: PSA   Contempora...   92
# 56  ATT TO {#9} |AWDESC=Insect Screen 1: 400 Serie...   93
# 57  ATT TO {#9} |AWDESC=Exterior Trim: [Configurat...   94
# 58  ATT TO {#9} |AWDESC=Decorative Trim: [Configur...   95
# 59  {#10} |AWDESC=400 Triple Horizontal Awning, 84...  101
# 60  ATT TO {#10} |AWDESC=Exterior Trim: [Configura...  102
# 61  ATT TO {#10} |AWDESC=Decorative Trim: [Configu...  103
#
# [62 rows x 12 columns]
